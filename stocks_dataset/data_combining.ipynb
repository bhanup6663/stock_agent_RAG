# %%
import yfinance as yf
import pandas as pd

# %%
def load_yahoo():
    tickers = ['AAL', 'AAPL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALLE', 'ALL', 'ALXN', 'AMAT', 'AMD', 'AME', 'AMGN', 'AMG', 'AMP', 'AMT', 'AMZN', 'ANDV', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APC', 'APD', 'APH', 'APTV', 'ARE', 'ARNC', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'A', 'BAC', 'BAX', 'BA', 'BBT', 'BBY', 'BDX', 'BEN', 'BF.B', 'BHF', 'BHGE', 'BIIB', 'BK', 'BLK', 'BLL', 'BMY', 'BRK.B', 'BSX', 'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA', 'CBG', 'CBOE', 'CBS', 'CB', 'CCI', 'CCL', 'CDNS', 'CELG', 'CERN', 'CFG', 'CF', 'CHD', 'CHK', 'CHRW', 'CHTR', 'CINF', 'CI', 'CLX', 'CL', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COL', 'COO', 'COP', 'COST', 'COTY', 'CPB', 'CRM', 'CSCO', 'CSRA', 'CSX', 'CTAS', 'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'C', 'DAL', 'DE', 'DFS', 'DGX', 'DG', 'DHI', 'DHR', 'DISCA', 'DISCK', 'DISH', 'DIS', 'DLR', 'DLTR', 'DOV', 'DPS', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DWDP', 'DXC', 'D', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'EOG', 'EQIX', 'EQR', 'EQT', 'ESRX', 'ESS', 'ES', 'ETFC', 'ETN', 'ETR', 'EVHC', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'FAST', 'FBHS', 'FB', 'FCX', 'FDX', 'FE', 'FFIV', 'FISV', 'FIS', 'FITB', 'FLIR', 'FLR', 'FLS', 'FL', 'FMC', 'FOXA', 'FOX', 'FRT', 'FTI', 'FTV', 'F', 'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GM', 'GOOGL', 'GOOG', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HOG', 'HOLX', 'HON', 'HPE', 'HPQ', 'HP', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IPG', 'IP', 'IQV', 'IRM', 'IR', 'ISRG', 'ITW', 'IT', 'IVZ', 'JBHT', 'JCI', 'JEC', 'JNJ', 'JNPR', 'JPM', 'JWN', 'KEY', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KORS', 'KO', 'KR', 'KSS', 'KSU', 'K', 'LB', 'LEG', 'LEN', 'LH', 'LKQ', 'LLL', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUK', 'LUV', 'LYB', 'L', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT', 'MA', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MON', 'MOS', 'MO', 'MPC', 'MRK', 'MRO', 'MSFT', 'MSI', 'MS', 'MTB', 'MTD', 'MU', 'MYL', 'M', 'NAVI', 'NBL', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NLSN', 'NOC', 'NOV', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'NWSA', 'NWS', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OXY', 'O', 'PAYX', 'PBCT', 'PCAR', 'PCG', 'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PGR', 'PG', 'PHM', 'PH', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL', 'PRGO', 'PRU', 'PSA', 'PSX', 'PVH', 'PWR', 'PXD', 'PX', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'REGN', 'REG', 'RE', 'RF', 'RHI', 'RHT', 'RJF', 'RL', 'RMD', 'ROK', 'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBAC', 'SBUX', 'SCG', 'SCHW', 'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SNPS', 'SO', 'SPGI', 'SPG', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ', 'SWKS', 'SWK', 'SYF', 'SYK', 'SYMC', 'SYY', 'TAP', 'TDG', 'TEL', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TPR', 'TRIP', 'TROW', 'TRV', 'TSCO', 'TSN', 'TSS', 'TWX', 'TXN', 'TXT', 'T', 'UAA', 'UAL', 'UA', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'UTX', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'V', 'WAT', 'WBA', 'WDC', 'WEC', 'WFC', 'WHR', 'WLTW', 'WMB', 'WMT', 'WM', 'WRK', 'WU', 'WYNN', 'WYN', 'WY', 'XEC', 'XEL', 'XLNX', 'XL', 'XOM', 'XRAY', 'XRX', 'XYL', 'YUM', 'ZBH', 'ZION', 'ZTS']
    data_yahoo = yf.download(tickers, start="2015-01-01", end="2023-01-01", group_by='ticker')
    stacked_data = data_yahoo.stack(level=0).reset_index()

    # Rename the columns to lowercase, consistent with previous renaming
    stacked_data.columns = ['date', 'Name', 'open', 'high', 'low', 'close', 'adj_close', 'volume']

    stacked_data['source'] = 'Yahoo Finance'
    
    return stacked_data

# %%
def load_sp500(filepath):
    sp500_data = pd.read_csv(filepath)
    sp500_data['source'] = 'SP500'
    sp500_data_cleaned = sp500_data.dropna()
    return sp500_data_cleaned

# %%
def load_tesla(filepath):
    tesla_data = pd.read_csv(filepath)
    tesla_data['name'] = 'Tesla'
    tesla_data['source'] = 'Kaggle'
    return tesla_data

# %%
yahoo_data=load_yahoo()
print(yahoo_data.columns)
print(yahoo_data.dtypes)
print(yahoo_data.head())
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 68 Failed downloads:
# ['DISCK', 'ADS', 'BHGE', 'XLNX', 'MON', 'VIAB', 'PKI', 'PBCT', 'CTL', 'RTN', 'TIF', 'TSS', 'AGN', 'NLSN', 'BBT', 'TMK', 'ABC', 'KSU', 'XL', 'FB', 'LLL', 'BRK.B', 'RHT', 'DISH', 'ALXN', 'XEC', 'RE', 'UTX', 'DWDP', 'JEC', 'MYL', 'ATVI', 'CBS', 'WLTW', 'CELG', 'CTXS', 'CXO', 'NBL', 'CERN', 'DISCA', 'ANTM', 'BLL', 'DRE', 'WRK', 'ARNC', 'FBHS', 'APC', 'VAR', 'SYMC', 'HRS', 'COG', 'ETFC', 'FLIR', 'PXD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['FISV', 'CA', 'INFO', 'LB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-01-01 -> 2023-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1420088400, endDate = 1672549200")')
# ['BF.B', 'PCLN', 'LUK', 'DPS', 'CBG', 'GGP', 'KORS', 'WYN', 'HCN']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-01-01 -> 2023-01-01)')
# ...

# %%
sp500_filepath='../../pre-analysis/datasets/archive/all_stocks_5yr.csv'
sp500_data=load_sp500(sp500_filepath)
print(sp500_data.columns)
print(sp500_data.dtypes)
print(sp500_data.head())
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'source'], dtype='object')
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# source     object
# dtype: object
#          date   open   high    low  close    volume Name source
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL  SP500
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL  SP500
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL  SP500
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL  SP500
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL  SP500

# %%
tesla_filepath='../../pre-analysis/datasets/TSLA.csv'
tesla_data=load_tesla(tesla_filepath)
print(tesla_data.columns)
print(tesla_data.dtypes)
print(tesla_data.head())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'name',
#        'source'],
#       dtype='object')
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# name          object
# source        object
# dtype: object
#          Date   Open   High    Low  Close  Adj Close    Volume   name  source
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500  Tesla  Kaggle
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500  Tesla  Kaggle
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000  Tesla  Kaggle
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000  Tesla  Kaggle
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500  Tesla  Kaggle

# %%
sp500_data.columns = ['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'source']

tesla_data.columns = ['date','open', 'high', 'low', 'close', 'adj_close', 'volume', 'Name', 'source']

# %%
print(yahoo_data.columns)
print(sp500_data.columns)
print(tesla_data.columns)
# Out:
# Index(['date', 'Name', 'open', 'high', 'low', 'close', 'adj_close', 'volume',
#        'source'],
#       dtype='object')
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'source'], dtype='object')
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume', 'Name',
#        'source'],
#       dtype='object')

# %%
yahoo_data['date'] = pd.to_datetime(yahoo_data['date']).dt.date
sp500_data['date'] = pd.to_datetime(sp500_data['date']).dt.date
tesla_data['date'] = pd.to_datetime(tesla_data['date']).dt.date

# %%
sp500_data['adj_close'] = pd.NA

# %%
print(yahoo_data.columns)
print(sp500_data.columns)
print(tesla_data.columns)
# Out:
# Index(['date', 'Name', 'open', 'high', 'low', 'close', 'adj_close', 'volume',
#        'source'],
#       dtype='object')
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'source',
#        'adj_close'],
#       dtype='object')
# Index(['date', 'open', 'high', 'low', 'close', 'adj_close', 'volume', 'Name',
#        'source'],
#       dtype='object')

# %%
yahoo_data.head()
# Out:
#          date  Name        open        high         low       close  \
# 0  2015-01-02     A   41.180000   41.310001   40.369999   40.560001
# 1  2015-01-02   AAL   54.279999   54.599998   53.070000   53.910000
# 2  2015-01-02   AAP  160.850006  162.500000  157.470001  158.559998
# 3  2015-01-02  AAPL   27.847500   27.860001   26.837500   27.332500
# 4  2015-01-02  ABBV   65.440002   66.400002   65.440002   65.889999
#
#     adj_close       volume         source
# 0   37.422043    1529200.0  Yahoo Finance
# 1   51.079910   10748600.0  Yahoo Finance
# 2  142.627365     509800.0  Yahoo Finance
# 3   24.373966  212818400.0  Yahoo Finance
# 4   43.563187    5086100.0  Yahoo Finance

# %%
sp500_data.head()
# Out:
#          date   open   high    low  close    volume Name source adj_close
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL  SP500      <NA>
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL  SP500      <NA>
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL  SP500      <NA>
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL  SP500      <NA>
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL  SP500      <NA>

# %%
tesla_data.head()
# Out:
#          date   open   high    low  close  adj_close    volume   Name  source
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500  Tesla  Kaggle
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500  Tesla  Kaggle
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000  Tesla  Kaggle
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000  Tesla  Kaggle
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500  Tesla  Kaggle

# %%
combined_data = pd.concat([yahoo_data, sp500_data, tesla_data], ignore_index=True)
# Out:
# /var/folders/wd/g8mvvv392p11yf16rzs6k9mr0000gn/T/ipykernel_47978/3479590502.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_data = pd.concat([yahoo_data, sp500_data, tesla_data], ignore_index=True)

# %%
combined_data.columns
# Out:
# Index(['date', 'Name', 'open', 'high', 'low', 'close', 'adj_close', 'volume',
#        'source'],
#       dtype='object')

# %%
print(combined_data.head())
# Out:
#          date  Name        open        high         low       close  \
# 0  2015-01-02     A   41.180000   41.310001   40.369999   40.560001
# 1  2015-01-02   AAL   54.279999   54.599998   53.070000   53.910000
# 2  2015-01-02   AAP  160.850006  162.500000  157.470001  158.559998
# 3  2015-01-02  AAPL   27.847500   27.860001   26.837500   27.332500
# 4  2015-01-02  ABBV   65.440002   66.400002   65.440002   65.889999
#
#     adj_close       volume         source
# 0   37.422043    1529200.0  Yahoo Finance
# 1   51.079910   10748600.0  Yahoo Finance
# 2  142.627365     509800.0  Yahoo Finance
# 3   24.373966  212818400.0  Yahoo Finance
# 4   43.563187    5086100.0  Yahoo Finance

# %%
summary_stats = combined_data.describe()
print(summary_stats)
# Out:
#                open          high           low         close      adj_close  \
# count  1.480161e+06  1.480161e+06  1.480161e+06  1.480161e+06  861132.000000
# mean   9.359987e+01  9.457148e+01  9.260193e+01  9.361001e+01      92.314489
# std    1.061895e+02  1.073096e+02  1.050207e+02  1.062015e+02     109.313477
# min    1.000000e-02  1.500000e-02  1.000000e-02  1.500000e-02       0.015000
# 25%    4.107000e+01  4.152000e+01  4.062000e+01  4.108000e+01      35.885409
# 50%    6.693000e+01  6.760000e+01  6.625000e+01  6.694000e+01      61.361471
# 75%    1.097300e+02  1.108100e+02  1.086100e+02  1.097500e+02     110.893282
# max    2.609290e+03  2.610050e+03  2.539360e+03  2.579000e+03    2579.000000
#
#              volume
# count  1.480161e+06
# mean   5.708521e+06
# std    2.300466e+07
# min    0.000000e+00
# 25%    1.116994e+06
# 50%    2.205000e+06
# 75%    4.719940e+06
# max    3.692928e+09

# %%
data_types = combined_data.dtypes
print(data_types)
# Out:
# date          object
# Name          object
# open         float64
# high         float64
# low          float64
# close        float64
# adj_close    float64
# volume       float64
# source        object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(data=combined_data[['open', 'high', 'low', 'close', 'volume']])
plt.show()

# %%
combined_data[['open', 'high', 'low', 'close']].set_index(combined_data['date']).plot(figsize=(10, 6))
plt.title('S&P 500 Stock Prices Over Time (Aggregated)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
sns.heatmap(combined_data[['open', 'high', 'low', 'close', 'volume']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for S&P 500 Stocks')
plt.show()

# %%
# Moving average for the 'close' price (aggregated)
combined_data['close'].rolling(window=20).mean().plot(figsize=(10, 6))
plt.title('20-Day Moving Average of Close Price (Aggregated)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
# Step 1: Handling erroneous values in 'adj_close'
# Replace negative or extreme 'adj_close' values with NaN
combined_data['adj_close'] = combined_data['adj_close'].apply(lambda x: np.nan if x < 0 else x)

# %%
# Step 2: Handling missing values
# Check for missing values
missing_values = combined_data.isnull().sum()
print("Missing values before imputation:\n", missing_values)
# Out:
# Missing values before imputation:
#  date              0
# Name              0
# open              0
# high              0
# low               0
# close             0
# adj_close    619029
# volume            0
# source            0
# dtype: int64

# %%
# Impute missing values for numeric columns using forward fill method (suitable for time series data)
combined_data.fillna(method='ffill', inplace=True)
# Out:
# /var/folders/wd/g8mvvv392p11yf16rzs6k9mr0000gn/T/ipykernel_47978/3804102024.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_data.fillna(method='ffill', inplace=True)

# %%
# Step 3: Removing or scaling outliers (focus on 'volume')
# Capping extreme values in 'volume' at the 99th percentile
volume_threshold = combined_data['volume'].quantile(0.99)
combined_data['volume'] = np.where(combined_data['volume'] > volume_threshold, volume_threshold, combined_data['volume'])

# %%
# Step 4: Normalizing data using Min-Max Scaling
scaler = MinMaxScaler()

# %%
# Apply scaling to numeric columns: 'open', 'high', 'low', 'close', 'adj_close', 'volume'
numerical_cols = ['open', 'high', 'low', 'close', 'adj_close', 'volume']
combined_data[numerical_cols] = scaler.fit_transform(combined_data[numerical_cols])

# %%
print("Missing values after imputation:\n", combined_data.isnull().sum())
combined_data.head()
# Out:
# Missing values after imputation:
#  date         0
# Name         0
# open         0
# high         0
# low          0
# close        0
# adj_close    0
# volume       0
# source       0
# dtype: int64
#          date  Name      open      high       low     close  adj_close  \
# 0  2015-01-02     A  0.015778  0.015822  0.015894  0.015721   0.014505
# 1  2015-01-02   AAL  0.020799  0.020914  0.020895  0.020898   0.019800
# 2  2015-01-02   AAP  0.061642  0.062254  0.062008  0.061476   0.055298
# 3  2015-01-02  AAPL  0.010669  0.010668  0.010565  0.010592   0.009445
# 4  2015-01-02  ABBV  0.025076  0.025435  0.025766  0.025543   0.016886
#
#      volume         source
# 0  0.028061  Yahoo Finance
# 1  0.197238  Yahoo Finance
# 2  0.009355  Yahoo Finance
# 3  1.000000  Yahoo Finance
# 4  0.093330  Yahoo Finance

# %%
sns.boxplot(data=combined_data[['open', 'high', 'low', 'close', 'volume']])
plt.show()

# %%
combined_data[['open', 'high', 'low', 'close']].set_index(combined_data['date']).plot(figsize=(10, 6))
plt.title('S&P 500 Stock Prices Over Time (Aggregated)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
sns.heatmap(combined_data[['open', 'high', 'low', 'close', 'volume']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for S&P 500 Stocks')
plt.show()

# %%
summary_stats = combined_data.describe()
print(summary_stats)
# Out:
#                open          high           low         close     adj_close  \
# count  1.480161e+06  1.480161e+06  1.480161e+06  1.480161e+06  1.480161e+06
# mean   3.586808e-02  3.622805e-02  3.646285e-02  3.629141e-02  4.419358e-02
# std    4.069687e-02  4.111422e-02  4.135732e-02  4.117959e-02  3.381550e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.573614e-02  1.590209e-02  1.599228e-02  1.592293e-02  2.067212e-02
# 50%    2.564692e-02  2.589429e-02  2.608541e-02  2.595013e-02  5.588509e-02
# 75%    4.204991e-02  4.244962e-02  4.276685e-02  4.254969e-02  5.588509e-02
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#              volume
# count  1.480161e+06
# mean   8.799126e-02
# std    1.469614e-01
# min    0.000000e+00
# 25%    2.049691e-02
# 50%    4.046189e-02
# 75%    8.661120e-02
# max    1.000000e+00

# %%
combined_data.to_csv('../../pre-analysis/datasets/processed_stock_dataset.csv', index=True)
